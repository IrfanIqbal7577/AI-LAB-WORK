# %%
result1 = ['naveed', 'amir', 'shakeela', 'Pdju']

result1_1 = ['naveed--> w-len:6 v-len:3 upper_len:0 lower_len:6',
         'amir--> w-len:4 v-len:2 upper_len:0 lower_len:4',
         'shakeela--> w-len:8 v-len:4 upper_len:0 lower_len:8',
         'Pdju--> w-len:4 v-len:1 upper_len:1 lower_len:3']

result1_2 = [['6', '3', '0', '6'],
 ['4', '2', '0', '4'],
 ['8', '4', '0', '8'],
 ['4', '1', '1', '3']]

result1_3 = [['6', '3', '0', '6'],
 ['4', '2', '0', '4'],
 ['8', '4', '0', '8'],
 ['4', '1', '1', '3'],
 ['22', '10', '1', '21']]

result2 = ['Al34i', 'Y7*U2', 'JU6I', '8K1i', 'amiQ2a', 'O36']

result2_1 = ['Al34i', ('num:34', 'num-sum:7'), ('upper:A--1', 'lower:li--2'), 17, (65, 213)]
        ['Y7*U2', ('num:72', 'num-sum:9'), ('upper:YU--2', 'lower:--0'), 20, (174, 0)]
        ['JU6I', ('num:6', 'num-sum:6'), ('upper:JUI--3', 'lower:--0'), 15, (232, 0)]
        ['8K1i', ('num:81', 'num-sum:9'), ('upper:K--1', 'lower:i--1'), 20, (75, 105)]
        ['amiQ2a', ('num:2', 'num-sum:2'), ('upper:Q--1', 'lower:amia--4'), 9, (81, 408)]
        ['O36', ('num:36', 'num-sum:9'), ('upper:O--1', 'lower:--0'), 19, (79, 0)]

# %%
list_raw=[('Al34i','naveed'),('amir','Y7*U2'),('JU6I','8K1i'),('shakeela','amiQ2a'),('Pdju','O36')]
list_alpha=[]
for a in list_raw:
    for a in a:
        if a.isalpha():

            list_alpha.append(a)

list_digit=[]

for a in list_raw:
    for a in a:
         if a.isnumeric():
             list_digit.append(a)



list_mix=[]

for a in list_raw:
    for a in a:
        if a.isalnum() and a.isnumeric()==False and a.isalpha()==False:
             list_mix.append(a)

print("Result_1=",list_alpha)




s='aeiouAEIOU'
v=[]
NameStrin=""
count=0
countU=0
countL=0
for words in list_mix : 
    for word in words:
       
        if word.upper()==word:
            countU+=1

        if word.lower()==word:
            countL+=1   
        if word in s:
            count=count+1
    v.append(words+"==> w_len "+str(len(words))+"==> upper_len"+str(countU)+"==> lower_len"+str(countL))
    count=0

print(v)

result = []

for i in v:
    col = []
    for a in i:
        if a.isdigit():
            lista = []
            col.append(a)
    result.append(col)

print(result)

print("Result_2=",list_mix)

s='aeiouAEIOU'
v=[]
NameStrin=""
count=0
countU=0
countL=0
for words in list_alpha : 
    for word in words:
       
        if word.upper()==word:
            countU+=1

        if word.lower()==word:
            countL+=1   
        if word in s:
            count=count+1
    v.append(words+"==> w_len "+str(len(words))+"==> upper_len"+str(countU)+"==> lower_len"+str(countL))
    count=0

print(v)
# Out:
# Result_1= ['naveed', 'amir', 'shakeela', 'Pdju']
# ['Al34i==> w_len 5==> upper_len3==> lower_len4', 'JU6I==> w_len 4==> upper_len7==> lower_len5', '8K1i==> w_len 4==> upper_len10==> lower_len8', 'amiQ2a==> w_len 6==> upper_len12==> lower_len13', 'O36==> w_len 3==> upper_len15==> lower_len15']
# [['3', '4', '5', '3', '4'], ['6', '4', '7', '5'], ['8', '1', '4', '1', '0', '8'], ['2', '6', '1', '2', '1', '3'], ['3', '6', '3', '1', '5', '1', '5']]
# Result_2= ['Al34i', 'JU6I', '8K1i', 'amiQ2a', 'O36']
# ['naveed==> w_len 6==> upper_len0==> lower_len6', 'amir==> w_len 4==> upper_len0==> lower_len10', 'shakeela==> w_len 8==> upper_len0==> lower_len18', 'Pdju==> w_len 4==> upper_len1==> lower_len21']

# %%
Write a Python program to get a string from a given string where all occurrences of its first char have been changed to '$', except the first char itself. 
Sample String : 'restart'
Expected Result : 'resta$t'

# %%
def change_char(str1): 
    char = str1[0]  
    length = len(str1)  
    str1 = str1.replace(char, '$')  
    str1 = char + str1[1:]    
    return str1 
 
print(change_char('restart'))
# Out:
# resta$t

# %%
Question#2)
I)calculate h(n)
II)calculate path cost
III)apply uniform cost search(UCS)
IV)apply Greedy best first search algorithm

# %%
def UCS(d,goal):
    
    q = []
    q.append(('s',0))
    explored = []
    
    while len(q)>0:

        print('Queue :  ',q)
        node = q.pop(0)
        print('child pop: ',node) # node[0] --> node name AND node[1] --> cost
        
        if node[0] not in explored:
            explored.append(node[0])
        
        if node[0] == goal:
            return explored 
        
        print('Explored: ',explored)

        child = d.get(node[0])
        print('current child: ',child)
        
        for i in child:
            print(i)
            
            cost =  i[1] + node[1]
            name = i[0]
            new = (name,cost)

            
            print('{} , parent cost ({}) + child cost ({}) = {}'.format(i,node[1],i[1],cost))
            #print('////\\\\ ',new)
            
            
            if new[0] not in explored and new[0] not in build_dcit(q):
                
                q.append(new) 
                
            
                
            elif new[0] in build_dcit(q):
                #rint('[[[[[[[[[[[[[[[duplicate]]]]]]]]]]]]]]]')

                #rint(new[0],build_dcit(q)[new[0]])

                old_data = build_dcit(q)
                old_cost = old_data[new[0]]
                old_name = new[0]
                old = (old_name,old_cost)

                #rint(old)
                #rint('NNNNNNNNNNNNNNNNNNNNNN',new , node)
                if new[1] < old[1]:
                    #rint('^^^^^^^*******%%%%%%%% in if')
                    inde = q.index(old)
                    q[inde] = new
                else:
                    pass

        
        q = sorted(q,key= my)
        #print(q)
        print(50*'*')

# %%
def GBFS(start,goal):
    
    q = []
    start_val = h_n_.get(start)
    q.append((start,start_val))
    explored = []
    expanded = []
    
    while len(q)>0:


        node = q.pop(0)

        if node[0] not in explored:
            explored.append(node[0])
        
        if node[0] == goal:
            print('Result :',explored,expanded,len(expanded))
            return

        child = d.get(node[0])
 
        for i in child:
            n_key = i[0]
            n_val = h_n_.get(n_key)
            n_tuple = n_key,n_val   

            if i[0] not in explored and i[0] not in build_dcit(q):
                q.append(n_tuple)
        expanded.append(node[0])
            
        q = sorted(q,key= my)
    return explored,expanded,len(expanded)
        
    
GBFS('s','g')

# %%
dd = {'s':[('a',3),('b',2),('c',4),('d',1)],
    'a':[('b',2)],
    'b':[('a',3),('c',4)],
    'c':[('f',3)],
    'd':[('c',4),('g',1)],
    'e':[('g',1)],
    'f':[('d',1),('g',5)]
    }

lis = [('a',3),('b',2),('c',4),('e',1)]
def my(x):
    return x[1]
lis = sorted(lis,key=my)
new = ('c',2)

def build_dcit(lis):
    di  = {}

    for i in lis:
        name = i[0]
        cost = i[1]
        di[name] = cost
    return di
new[0] in build_dcit(lis)


def build_dcitt(lis):
    di  = {}

    for i in lis:

        di[i[0]] = i[1]
    return di
new[0] in build_dcitt(lis)



def build_dcitt(lis):
     
    return {i[0] :i[1] for i in lis }


new[0] in build_dcitt(lis)


for i in lis:
    
    
    if (i[0] == new [0]):
        print(i)
        if i[1]<new[1]:
            pass
        else:
            ind = lis.index(i)
            lis[ind] = new
            
            
            

            
            
def UCS(d,goal):
    
    q = []
    q.append(('s',0))
    explored = []
    
    while len(q)>0:

        print('Queue :  ',q)
        node = q.pop(0)
        print('child pop: ',node) # node[0] --> node name AND node[1] --> cost
        
        if node[0] not in explored:
            explored.append(node[0])
        
        if node[0] == goal:
            return explored 
        
        print('Explored: ',explored)

        child = d.get(node[0])
        print('current child: ',child)
        
        for i in child:
            print(i)
            
            cost =  i[1] + node[1]
            name = i[0]
            new = (name,cost)

            
            print('{} , parent cost ({}) + child cost ({}) = {}'.format(i,node[1],i[1],cost))
            #print('////\\\\ ',new)
            
            
            if new[0] not in explored and new[0] not in build_dcit(q):
                
                q.append(new) 
                
            
                
            elif new[0] in build_dcit(q):
                #rint('[[[[[[[[[[[[[[[duplicate]]]]]]]]]]]]]]]')

                #rint(new[0],build_dcit(q)[new[0]])

                old_data = build_dcit(q)
                old_cost = old_data[new[0]]
                old_name = new[0]
                old = (old_name,old_cost)

                #rint(old)
                #rint('NNNNNNNNNNNNNNNNNNNNNN',new , node)
                if new[1] < old[1]:
                    #rint('^^^^^^^***%%%%%%%% in if')
                    inde = q.index(old)
                    q[inde] = new
                else:
                    pass

        
        q = sorted(q,key= my)
        #print(q)
        print(50*'*')
        
    
UCS(dd,'g')





s = []
s.append(('S',0))
s



def UCS_new(d,goal):
    
    q = []
    q.append(('s',0))
    explored = []
    
    while len(q)>0:

        print('Queue :  ',q)
        node = q.pop(0)   
        
        if node[0] not in explored:
            explored.append(node[0])
        
        if node[0] == goal:
            return explored 
        
        child = d.get(node[0])
              
        for i in child:

            cost =  i[1] + node[1]
            name = i[0]
            new = (name,cost)

            if new[0] not in explored and new[0] not in build_dcit(q):
                
                q.append(new) 

            elif new[0] in build_dcit(q):

                old_data = build_dcit(q)
                old_cost = old_data[new[0]]
                old_name = new[0]
                old = (old_name,old_cost)

                if new[1] < old[1]:

                    inde = q.index(old)
                    q[inde] = new
                else:
                    pass

        
        q = sorted(q,key= my)
        print(50*'*')
        
    
UCS_new(dd,'g')




import time

strat =  time.time()
UCS_new(dd,'g')
end =  time.time()
total = end-strat
total


import random
BFS
1000 , 2.3
40000 , 3.5 

4000000 , 6.2

3403490934 , 2.3

[10000,400000,]
DFS
1000 , 4.3
40000 , 2.5 

4000000 , 7.2

3403490934 , 2.3
li = []

for i in range(1000):
    
    rand = random.randint(0,50)
    li.append(rand)
len(set(li))
list(set( random.randint(0,50000) for i in range(1000)))
# Out:
# ('c', 4)
# Queue :   [('s', 0)]
# child pop:  ('s', 0)
# Explored:  ['s']
# current child:  [('a', 3), ('b', 2), ('c', 4), ('d', 1)]
# ('a', 3)
# ('a', 3) , parent cost (0) + child cost (3) = 3
# ('b', 2)
# ('b', 2) , parent cost (0) + child cost (2) = 2
# ('c', 4)
# ('c', 4) , parent cost (0) + child cost (4) = 4
# ('d', 1)
# ('d', 1) , parent cost (0) + child cost (1) = 1
# **************************************************
# Queue :   [('d', 1), ('b', 2), ('a', 3), ('c', 4)]
# child pop:  ('d', 1)
# Explored:  ['s', 'd']
# current child:  [('c', 4), ('g', 1)]
# ('c', 4)
# ('c', 4) , parent cost (1) + child cost (4) = 5
# ('g', 1)
# ('g', 1) , parent cost (1) + child cost (1) = 2
# **************************************************
# Queue :   [('b', 2), ('g', 2), ('a', 3), ('c', 4)]
# child pop:  ('b', 2)
# Explored:  ['s', 'd', 'b']
# current child:  [('a', 3), ('c', 4)]
# ('a', 3)
# ('a', 3) , parent cost (2) + child cost (3) = 5
# ('c', 4)
# ...
